# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import nltk
#nltk.download('stopwords')

# %%
from nltk.corpus import stopwords

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/MTP after 15/TEXT_CLASSIFICATION/TEXT_DATA_NAIVE_BAYES_CLASSIFICATION_new.xlsx')

# %%
df
# Out:
#                                                   text class
# 0    This appeal is directed against the final judg...     f
# 1    Brief facts: ) Respondent No. 1-the Contractee...     f
# 2    On 21.09.2012, the Contractee Company submitte...     f
# 3    Subsequently, on 24.10.2012, the Contractee Co...     f
# 4    The Contractee-Company, vide letter dated 12.0...     f
# ..                                                 ...   ...
# 355  Turning now to the merits of the challenge, th...     r
# 356  In the course of the award albeit while dealin...     d
# 357  On the question of payment of supervision char...     r
# 358  In view of my finding above, that the order of...     r
# 359  Apart from the consultancy and supervision cha...     r
#
# [360 rows x 2 columns]

# %%
df['class'].value_counts()
# Out:
# r    159
# f     87
# a     75
# d     39
# Name: class, dtype: int64

# %%
import string

# %%
df
# Out:
#                                                   text class
# 0    This appeal is directed against the final judg...     f
# 1    Brief facts: ) Respondent No. 1-the Contractee...     f
# 2    On 21.09.2012, the Contractee Company submitte...     f
# 3    Subsequently, on 24.10.2012, the Contractee Co...     f
# 4    The Contractee-Company, vide letter dated 12.0...     f
# ..                                                 ...   ...
# 330  It is submitted by the petitioner that the ana...     f
# 331  The decision in terms of the Note of the petit...     f
# 332  A reading of the above would show that the Arb...     r
# 333  In view of the above, the submission of the co...     r
# 334  he Arbitral Tribunal has further considered th...     r
#
# [335 rows x 2 columns]

# %%
def text_cleaning(a):
  remove_punctuation = [char for char in a if char not in string.punctuation]
  remove_punctuation = ''.join(remove_punctuation)
  return [word for word in remove_punctuation.split()] #if word.lower() not in stopwords.words('english')]

# %%
print(df.iloc[:,0].apply(text_cleaning))
# Out:
# 0      [This, appeal, is, directed, against, the, fin...
# 1      [Brief, facts, Respondent, No, 1the, Contracte...
# 2      [On, 21092012, the, Contractee, Company, submi...
# 3      [Subsequently, on, 24102012, the, Contractee, ...
# 4      [The, ContracteeCompany, vide, letter, dated, ...
#                              ...
# 355    [Turning, now, to, the, merits, of, the, chall...
# 356    [In, the, course, of, the, award, albeit, whil...
# 357    [On, the, question, of, payment, of, supervisi...
# 358    [In, view, of, my, finding, above, that, the, ...
# 359    [Apart, from, the, consultancy, and, supervisi...
# Name: text, Length: 360, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
bow_transformer = CountVectorizer(analyzer = text_cleaning).fit(df['text'])

# %%
bow_transformer.vocabulary_
# Out:
# {'This': 1508,
#  'appeal': 1742,
#  'is': 2960,
#  'directed': 2344,
#  'against': 1668,
#  'the': 4064,
#  'final': 2646,
#  'judgment': 2977,
#  'and': 1727,
#  'order': 3313,
#  'dated': 2245,
#  '12012015': 62,
#  'passed': 3362,
#  'by': 1937,
#  'High': 933,
#  'Court': 771,
#  'of': 3283,
#  'Karnataka': 1013,
#  'at': 1832,
#  'Bengaluru': 641,
#  'in': 2852,
#  'CMP': 684,
#  'No': 1151,
#  '35': 375,
#  '2014': 234,
#  'whereby': 4265,
#  'learned': 3027,
#  'single': 3891,
#  'Judge': 1001,
#  'allowed': 1694,
#  'petition': 3402,
#  'filed': 2644,
#  'respondent': 3752,
#  '1': 31,
#  'Company': 733,
#  'for': 2672,
#  'appointment': 1763,
#  'an': 1721,
#  'arbitrator': 1784,
#  'resolution': 3740,
#  'dispute': 2376,
#  'between': 1899,
#  'appellantCompany': 1746,
#  'Signature': 1434,
#  'Not': 1181,
#  'Verified': 1545,
#  'ASHA': 528,
#  'SUNDRIYAL': 1403,
#  'Date': 787,
#  '20180207': 239,
#  '1Company': 205,
#  'Brief': 660,
#  'facts': 2617,
#  'Respondent': 1332,
#  '1the': 210,
#  'Contractee': 756,
#  'was': 4245,
#  'awarded': 1857,
#  'a': 1584,
#  'Contract': 755,
#  'Site': 1441,
#  'Grading': 915,
#  'Construction': 750,
#  'Roads': 1343,
#  'Water': 1559,
#  'Drains': 815,
#  'Compound': 740,
#  'Wall': 1558,
#  'Aromatic': 603,
#  'Complex': 739,
#  'Mangalore': 1086,
#  'SEZ': 1396,
#  'appellantContractor': 1748,
#  'on': 3293,
#  '17032008': 132,
#  'The': 1498,
#  'total': 4107,
#  'contract': 2165,
#  'value': 4205,
#  'as': 1808,
#  'per': 3377,
#  'Letter': 1049,
#  'Acceptance': 533,
#  'LOA': 1033,
#  'Rs': 1346,
#  '1632568576': 123,
#  'which': 4268,
#  'subsequently': 3983,
#  'revised': 3777,
#  'to': 4102,
#  '195682439902': 171,
#  'vide': 4221,
#  'letter': 3041,
#  '20092010': 228,
#  'completion': 2067,
#  'period': 3388,
#  'also': 1701,
#  'extended': 2597,
#  'upto': 4188,
#  '30112010': 346,
#  'On': 1204,
#  '21092012': 246,
#  'submitted': 3979,
#  'DuesNo': 818,
#  'Claim': 712,
#  'Certificate': 697,
#  'certifying': 1987,
#  'payment': 3370,
#  'all': 1688,
#  'bills': 1908,
#  'settlement': 3851,
#  'claims': 2016,
#  'whatsoever': 4260,
#  'Thereafter': 1501,
#  '10102012': 38,
#  'appellant': 1745,
#  'hereinthe': 2794,
#  'Contractor': 758,
#  'made': 3086,
#  'bill': 1907,
#  '2034': 240,
#  'crores': 2229,
#  'Subsequently': 1465,
#  '24102012': 273,
#  'withdrew': 4286,
#  'stating': 3937,
#  'that': 4061,
#  'it': 2967,
#  'prerequisite': 3473,
#  'condition': 2092,
#  'release': 3687,
#  'their': 4065,
#  'long': 3073,
#  'due': 2402,
#  'legitimate': 3038,
#  'works': 4304,
#  'executed': 2564,
#  'under': 4143,
#  'same': 3807,
#  'furnished': 2716,
#  'duress': 2406,
#  'coercion': 2029,
#  'ContracteeCompany': 757,
#  '12012013': 61,
#  'claim': 2009,
#  '96884864200': 516,
#  'losses': 3078,
#  'incurred': 2873,
#  'during': 2408,
#  'execution': 2566,
#  '19062013': 159,
#  'issued': 2964,
#  'Completion': 738,
#  'have': 2775,
#  'been': 1886,
#  'completed': 2064,
#  'respects': 3751,
#  'no': 3209,
#  'certificate': 1984,
#  'has': 2774,
#  'After': 549,
#  'several': 3856,
#  'communication': 2048,
#  'writing': 4307,
#  '25072013': 280,
#  'denied': 2298,
#  'contracteeCompany': 2168,
#  'Vide': 1547,
#  '14092013': 98,
#  'sent': 3840,
#  'notice': 3239,
#  'resolving': 3743,
#  'parties': 3356,
#  'through': 4093,
#  'Arbitration': 594,
#  'envisaged': 2503,
#  'Article': 604,
#  '9020': 510,
#  'appointed': 1761,
#  'Mr': 1116,
#  'K': 1010,
#  'Mohandas': 1112,
#  'Former': 888,
#  'General': 905,
#  'Manager': 1084,
#  'Law': 1042,
#  'SBI': 1389,
#  'its': 2970,
#  'Arbitrator': 595,
#  '18102013': 145,
#  'request': 3726,
#  'not': 3235,
#  'tenable': 4045,
#  'law': 3019,
#  'Being': 638,
#  'aggrieved': 1675,
#  'decision': 2257,
#  'referring': 3652,
#  'preferred': 3466,
#  'before': 1887,
#  'Bangalore': 633,
#  'Learned': 1045,
#  'appellantContactor': 1747,
#  'this': 4086,
#  'way': 4247,
#  'special': 3911,
#  'leave': 3028,
#  'Heard': 931,
#  'PS': 1227,
#  'Narasimha': 1141,
#  'senior': 3838,
#  'counsel': 2206,
#  'P': 1217,
#  'Vinay': 1550,
#  'Kumar': 1025,
#  'Respondents': 1335,
#  'Contractorthe': 762,
#  'strenuously': 3963,
#  'contended': 2153,
#  'erred': 2513,
#  'holding': 2804,
#  'established': 2523,
#  'case': 1963,
#  'show': 3869,
#  'there': 4069,
#  'genuine': 2731,
#  'serious': 3843,
#  'regarding': 3666,
#  'Dues': 817,
#  'CertificateNo': 698,
#  'duresscoercion': 2407,
#  'erroneous': 2514,
#  'unsustainable': 4176,
#  'further': 2719,
#  'withholding': 4290,
#  'extension': 2599,
#  'granted': 2751,
#  'subject': 3972,
#  'contracteeCompanys': 2169,
#  'does': 2390,
#  'provide': 3544,
#  'escalation': 2519,
#  'costs': 2203,
#  'delay': 2285,
#  'arise': 1797,
#  'because': 1883,
#  'Clause': 716,
#  '6400': 466,
#  'obligation': 3266,
#  'cast': 1967,
#  'upon': 4187,
#  'pay': 3367,
#  'RA': 1298,
#  'Bills': 650,
#  'full': 2712,
#  'but': 1936,
#  'be': 1878,
#  'done': 2392,
#  'merely': 3133,
#  'assessment': 1822,
#  'Engineerin': 845,
#  'charge': 1995,
#  'few': 2638,
#  'letters': 3042,
#  'exchanged': 2559,
#  'much': 3175,
#  'prior': 3500,
#  'Final': 877,
#  'Bill': 649,
#  'In': 964,
#  'fact': 2612,
#  'alleged': 1690,
#  'were': 4257,
#  'never': 3206,
#  'brought': 1929,
#  'up': 4181,
#  'time': 4097,
#  'issuance': 2962,
#  'or': 3311,
#  'now': 3250,
#  'stage': 3921,
#  'open': 3300,
#  'raise': 3583,
#  'issue': 2963,
#  'finally': 2648,
#  'when': 4261,
#  'both': 1920,
#  'confirm': 2100,
#  'fully': 2713,
#  'discharged': 2355,
#  'performance': 3383,
#  'obligations': 3267,
#  'are': 1789,
#  'outstanding': 3332,
#  'disputes': 2378,
#  'court': 2216,
#  'will': 4279,
#  'refer': 3648,
#  'subsequent': 3982,
#  'arbitration': 1783,
#  'There': 1500,
#  'complete': 2063,
#  'accord': 1602,
#  'satisfaction': 3810,
#  'nothing': 3238,
#  'left': 3032,
#  'either': 2453,
#  'right': 3786,
#  'allowing': 1695,
#  'out': 3325,
#  'amount': 1717,
#  'Per': 1244,
#  'contra': 2164,
#  'contracteeRespondent': 2170,
#  'herein': 2789,
#  'contractee': 2167,
#  'raised': 3584,
#  'Running': 1385,
#  'Account': 536,
#  'ContractorCompany': 759,
#  'expenses': 2581,
#  'towards': 4111,
#  'carrying': 1961,
#  'construction': 2136,
#  'work': 4299,
#  'cleared': 2023,
#  'with': 4283,
#  'inordinate': 2902,
#  'even': 2534,
#  'tune': 4130,
#  'released': 3688,
#  'only': 3297,
#  'Upon': 1534,
#  'submitting': 3980,
#  'above': 1588,
#  'approving': 1776,
#  'carried': 1959,
#  'since': 3889,
#  'clearing': 2024,
#  'dues': 2403,
#  'payable': 3368,
#  'always': 1708,
#  'mercy': 3132,
#  'from': 2707,
#  'very': 4217,
#  'beginning': 1889,
#  'last': 3014,
#  'bank': 1869,
#  'guarantee': 2761,
#  'deliberately': 2288,
#  'withheld': 4287,
#  'got': 2745,
#  '30062011': 341,
#  'after': 1665,
#  'submission': 3975,
#  'NoDues': 1178,
#  'prima': 3493,
#  'facie': 2611,
#  'evident': 2542,
#  'requires': 3734,
#  'clauses': 2020,
#  'adjudicate': 1634,
#  'cause': 1973,
#  'grave': 2753,
#  'injustice': 2900,
#  'party': 3359,
#  'if': 2824,
#  'adjudicated': 1635,
#  'terms': 4055,
#  'these': 4078,
#  'circumstances': 2002,
#  'withdrawal': 4284,
#  'given': 2735,
#  'afterthought': 1666,
#  'number': 3254,
#  'decisions': 2258,
#  'held': 2784,
#  'who': 4271,
#  'discharge': 2354,
#  'agreement': 1679,
#  'voucher': 4238,
#  'alleges': 1691,
#  'such': 3997,
#  'document': 2387,
#  'account': 1607,
#  'fraudcoercionundue': 2700,
#  'influence': 2890,
#  'practiced': 3451,
#  'other': 3320,
#  'then': 4068,
#  'would': 4305,
#  'rendered': 3706,
#  'void': 4235,
#  'cannot': 1951,
#  'acted': 1614,
#  'could': 2205,
#  'continue': 2162,
#  'various': 4211,
#  'reasons': 3612,
#  'like': 3054,
#  'pooja': 3435,
#  'shifting': 3858,
#  'idols': 2822,
#  'nonavailability': 3225,
#  'free': 2701,
#  'encumbrance': 2474,
#  'site': 3893,
#  'obstruction': 3275,
#  'blasting': 1913,
#  'stoppage': 3956,
#  'hard': 2772,
#  'rock': 3793,
#  'issues': 2965,
#  'respect': 3748,
#  'local': 3068,
#  'contractors': 2176,
#  'nonvacation': 3232,
#  'project': 3528,
#  'displaced': 2372,
#  'families': 2631,
#  'permission': 3391,
#  'forest': 2677,
#  'clearance': 2022,
#  'wooden': 4294,
#  'logs': 3072,
#  'etc': 2532,
#  'huge': 2815,
#  'expenditure': 2580,
#  'disclosed': 2356,
#  'factors': 2616,
#  'attributable': 1840,
#  'owing': 3337,
#  'pending': 3376,
#  'rightly': 3787,
#  'withdrawn': 4285,
#  'Further': 895,
#  'clause': 2019,
#  'invoke': 2951,
#  'interference': 2925,
#  'sought': 3908,
#  'regard': 3664,
#  'ContractorONGC': 760,
#  'Petrochemicals': 1248,
#  'Ltd': 1064,
#  'invited': 2946,
#  'tender': 4046,
#  'Award': 619,
#  'Work': 1569,
#  'Storm': 1457,
#  'bid': 1902,
#  'Ms': 1123,
#  'Toyo': 1514,
#  'Engineering': 848,
#  'India': 966,
#  'Limited': 1055,
#  'TEILRespondent': 1481,
#  '2': 211,
#  'behalf': 1890,
#  'OMPL': 1193,
#  'contractor': 2171,
#  'being': 1892,
#  'Project': 1285,
#  'Management': 1083,
#  'Consultant': 753,
#  'ANS': 525,
#  'Constructions': 751,
#  'LimitedRespondent': 1057,
#  '15112007': 112,
#  'Value': 1540,
#  'estimated': 2527,
#  'later': 3016,
#  'pursuant': 3562,
#  'thereto': 4076,
#  'During': 821,
#  'subsistence': 3986,
#  'It': 984,
#  'record': 3632,
#  'requests': 3729,
#  'clear': 2021,
#  'paid': 3341,
#  'them': 4066,
#  'compelled': 2053,
#  'file': 2643,
#  'get': 2732,
#  'contractorCompany': 2172,
#  'rejected': 3677,
#  'ground': 2759,
#  'obtained': 3276,
#  'wrong': 4309,
#  'incorrect': 2868,
#  'rejection': 3679,
#  'invoked': 2952,
#  'declined': 2264,
#  'nominate': 3220,
#  'Civil': 711,
#  'Miscellaneous': 1109,
#  'Petition': 1246,
#  'Section': 1415,
#  '11': 48,
#  'Conciliation': 741,
#  'Act': 537,
#  '1996': 197,
#  'short': 3863,
#  'lieu': 3051,
#  'nominee': 3221,
#  'so': 3899,
#  'said': 3804,
#  'along': 1698,
#  'already': 1700,
#  'agree': 1676,
#  'thirdpresiding': 4084,
#  'constitution': 2133,
#  'three': 4092,
#  'member': 3128,
#  'Arbitral': 593,
#  'Tribunal': 1518,
#  'agreed': 1677,
#  'adjudicating': 1636,
#  'arising': 1800,
#  'taking': 4037,
#  'us': 4190,
#  'material': 3107,
#  'come': 2034,
#  'end': 2475,
#  'therein': 4073,
#  'point': 3430,
#  'raising': 3585,
#  'belated': 1893,
#  'form': 2681,
#  'too': 4105,
#  'well': 4255,
#  'support': 4020,
#  'his': 2801,
#  'relied': 3693,
#  'Union': 1531,
#  'Others': 1212,
#  'vs': 4240,
#  'Master': 1091,
#  'Co': 721,
#  '2011': 230,
#  '12': 60,
#  'SCC': 1393,
#  '349': 373,
#  'wherein': 4266,
#  'When': 1563,
#  'we': 4248,
#  'signed': 3880,
#  'voucherreceipt': 4239,
#  'one': 3296,
#  'validly': 4203,
#  'voluntarily': 4236,
#  'If': 962,
#  'practised': 3452,
#  'able': 1586,
#  'establish': 2522,
#  'obviously': 3279,
#  'agreementvoucher': 1681,
#  'Consequently': 746,
#  'any': 1737,
#  'arbitrable': 1779,
#  'But': 672,
#  'appears': 1744,
#  'lacking': 3005,
#  'credibility': 2224,
#  'courts': 2217,
#  'hand': 2768,
#  'assertion': 1820,
#  'coercionundue': 2030,
#  'while': 4270,
#  'basing': 1876,
#  'releasing': 3689,
#  'Whether': 1565,
#  'exerted': 2571,
#  'examined': 2546,
#  'keeping': 2993,
#  'mind': 3143,
#  'background': 1864,
#  'categorically': 1968,
#  'relevant': 3691,
#  'dates': 2246,
#  'our': 3324,
#  'perusal': 3399,
#  'making': 3095,
#  'payments': 3371,
#  'suppliers': 4016,
#  'others': 3321,
#  'advertently': 1655,
#  'delayed': 2286,
#  'causing': 1976,
#  'financial': 2649,
#  'crisis': 2225,
#  'carry': 1960,
#  'settling': 3852,
#  'periodically': 3389,
#  'However': 942,
#  'side': 3876,
#  'considering': 2123,
#  'conduct': 2094,
#  'reflected': 3655,
#  'correspondence': 2199,
#  'disclosing': 2357,
#  'encountered': 2473,
#  'constraints': 2134,
#  'Pursuant': 1291,
#  'false': 2630,
#  'filing': 2645,
#  'claimed': 2014,
#  'Idols': 961,
#  '660': 470,
#  'Conditions': 743,
#  'deals': 2252,
#  'Claims': 715,
#  '6610': 471,
#  'states': 3935,
#  'extra': 2603,
#  'compensation': 2055,
#  'remuneration': 3705,
#  'shall': 3857,
#  'give': 2734,
#  'within': 4291,
#  '10': 32,
#  'days': 2248,
#  'date': 2244,
#  'orders': 3315,
#  'instructions': 2915,
#  'related': 3683,
#  'additional': 1625,
#  'particulars': 3355,
#  'nature': 3192,
#  'grounds': 2760,
#  'based': 1874,
#  'Unless': 1533,
#  'until': 4178,
#  'liable': 3049,
#  '6630': 472,
#  'accordance': 1603,
#  'separately': 3842,
#  'included': 2863,
#  'prepared': 3471,
#  'Statement': 1453,
#  'giving': 2737,
#  'supported': 4021,
#  'copy': 2191,
#  'notified': 3242,
#  'specifically': 3913,
#  'provisions': 3553,
#  'deemed': 2272,
#  'waived': 4241,
#  'From': 893,
#  'materials': 3109,
#  'find': 2650,
#  'had': 2766,
#  'received': 3618,
#  'thereafter': 4070,
#  'ie': 2823,
#  'issuing': 2966,
#  'Apart': 579,
#  'mutually': 3179,
#  'accepting': 1601,
#  'quantum': 3574,
#  'conducting': 2096,
#  'measurements': 3121,
#  'arriving': 1805,
#  'required': 3731,
#  'accepted': 1600,
#  'We': 1560,
#  'considered': 2122,
#  'opinion': 3306,
#  'presents': 3478,
#  'mutual': 3178,
#  'rights': 3788,
#  'merge': 3134,
#  'remains': 3700,
#  'liabilities': 3047,
#  'With': 1568,
#  'prove': 3541,
#  'itself': 2971,
#  'provided': 3545,
#  'turn': 4131,
#  'around': 1802,
#  'say': 3815,
#  'still': 3947,
#  'story': 3960,
#  'about': 1587,
#  'visualised': 4232,
#  'earlier': 2440,
#  'As': 606,
#  'kind': 2995,
#  'Mere': 1102,
#  'allegation': 1689,
#  'noclaim': 3219,
#  'certificates': 1985,
#  'without': 4292,
#  'anything': 1738,
#  'more': 3168,
#  'suggest': 4005,
#  'lead': 3024,
#  'clearly': 2025,
#  'shows': 3873,
#  'Conclusion': 742,
#  'Admittedly': 547,
#  'gap': 2722,
#  'month': 3164,
#  '3': 335,
#  '½': 4326,
#  'half': 2767,
#  'months': 3166,
#  'whereas': 4264,
#  'settled': 3850,
#  'creates': 2222,
#  'iota': 2955,
#  'doubt': 2395,
#  'why': 4276,
#  'absence': 1590,
#  'exercising': 2570,
#  'view': 4222,
#  'plea': 3425,
#  'bereft': 1897,
#  'details': 2324,
#  'bald': 1867,
#  'really': 3602,
#  'existed': 2574,
#  'exercise': 2568,
#  'power': 3447,
#  'therefore': 4072,
#  'justified': 2990,
#  'dispose': 2374,
#  'two': 4133,
#  'OMPs': 1194,
#  'Both': 657,
#  'cases': 1965,
#  'taken': 4035,
#  'together': 4104,
#  'challenge': 1988,
#  'relates': 3684,
#  'interpretation': 2931,
#  'subclause': 3971,
#  '703': 480,
#  'xi': 4315,
#  'COPA': 685,
#  'although': 1706,
#  'entered': 2492,
#  'into': 2938,
#  'independent': 2875,
#  'agreements': 1680,
#  'relating': 3685,
#  'Price': 1275,
#  'Adjustment': 545,
#  'Formula': 889,
#  'identical': 2819,
#  'OMP': 1191,
#  '4722013': 419,
#  'present': 3477,
#  'award': 1855,
#  '5': 426,
#  'th': 4059,
#  'January': 998,
#  '2013': 233,
#  'claimantContractor': 2012,
#  'petitioner': 3403,
#  '4': 397,
#  'lane': 3010,
#  'Km': 1019,
#  '20800': 241,
#  '25170': 285,
#  'Ayodhya': 622,
#  'Gorakhpur': 912,
#  'National': 1144,
#  'Highway28': 934,
#  'Uttar': 1536,
#  'Pradesh': 1269,
#  'Pkg': 1255,
#  'LMNHPEWII': 1031,
#  'WBpackage6': 1555,
#  '15': 107,
#  'July': 1003,
#  '2005': 221,
#  '19th': 204,
#  'October': 1200,
#  'sum': 4008,
#  'Rs2626020168': 1361,
#  'stipulated': 3949,
#  '36': 378,
#  'ending': 2477,
#  '23rd': 266,
#  '2008': 225,
#  'NHAI': 1133,
#  '15th': 117,
#  'December': 790,
#  '2010': 229,
#  'Under': 1527,
#  'entitled': 2499,
#  'price': 3490,
#  'adjustment': 1640,
#  'formula': 2687,
#  'incorporated': 2867,
#  'Interim': 978,
#  'Payment': 1243,
#  'Certificates': 699,
#  'hereinafter': 2791,
#  'referred': 3651,
#  'IPCs': 955,
#  '19': 153,
#  '20th': 242,
#  'IPC': 951,
#  'onward': 3298,
#  'introduced': 2939,
#  'different': 2338,
#  'calculation': 1943,
#  'percentages': 3380,
#  'bitumen': 1911,
#  'cement': 1980,
#  'steel': 3944,
#  'XYZ': 1576,
#  'attempted': 1836,
#  'recovery': 3640,
#  'money': 3163,
#  'over': 3333,
#  'percentage': 3379,
#  'factor': 2614,
#  'unilaterally': 4163,
#  'changed': 1993,
#  'method': 3138,
#  'calculating': 1942,
#  'till': 4095,
#  'cost': 2201,
#  'used': 4193,
#  'Engineer': 844,
#  'authority': 1847,
#  'determine': 2328,
#  'interpret': 2930,
#  'Uptil': 1535,
#  'interpreted': 2932,
#  'pertaining': 3397,
#  'particular': 3353,
#  'manner': 3102,
#  'undisputed': 4151,
#  'requirement': 3732,
#  'change': 1992,
#  'arose': 1801,
#  'internal': 2928,
#  'audit': 1841,
#  'auditors': 1843,
#  'pointed': 3431,
#  'calculated': 1941,
#  'stood': 3955,
#  '28': 311,
#  'bids': 1906,
#  'report': 3717,
#  '2007': 223,
#  'March': 1088,
#  'communicated': 2047,
#  '28th': 324,
#  '2009': 227,
#  'original': 3318,
#  '40': 398,
#  'signing': 3883,
#  '25th': 288,
#  'visit': 4231,
#  'Director': 804,
#  'PD': 1220,
#  'advised': 1657,
#  'Team': 1487,
#  'Leader': 1044,
#  'revise': 3776,
#  'altered': 1703,
#  'sub': 3970,
#  'Aggrieved': 553,
#  'unilateral': 4162,
#  'took': 4106,
#  'matter': 3110,
#  '26th': 301,
#  'Engineers': 849,
#  'Even': 855,
#  '21st': 253,
#  'November': 1185,
#  'wrote': 4313,
#  'back': 1862,
#  'footnote': 2671,
#  'actual': 1619,
#  'procurement': 3515,
#  'articles': 1807,
#  'they': 4079,
#  'use': 4192,
#  'instructed': 2914,
#  'petitioners': 3404,
#  'Dispute': 808,
#  'Resolution': 1330,
#  'Board': 654,
#  'DRB': 781,
#  'consisting': 2128,
#  'experts': 2583,
#  'field': 2641,
#  'finding': 2651,
#  'favour': 2634,
#  'opined': 3305,
#  'correct': 2193,
#  'basis': 1877,
#  'however': 2813,
#  'did': 2336,
#  'accept': 1596,
#  'findings': 2652,
#  'Before': 637,
#  'contention': 2156,
#  'component': 2071,
#  'base': 1873,
#  'rate': 3587,
#  'prevailing': 3484,
#  'closing': 2028,
#  'argued': 1793,
#  'words': 4298,
#  'note': 3236,
#  'underneath': 4146,
#  'notional': 3245,
#  'Labour': 1037,
#  'Plant': 1258,
#  'Machinery': 1077,
#  'Spares': 1447,
#  'POL': 1225,
#  'spirit': 3918,
#  'behind': 1891,
#  'nobody': 3218,
#  'should': 3868,
#  'suffer': 4000,
#  'gain': 2721,
#  'term': 4050,
#  'understood': 4148,
#  'business': 1935,
#  'commonsense': 2046,
#  'engineer': 2483,
#  'forced': 2674,
#  'unambiguous': 4140,
#  'understanding': 4147,
#  'stipulation': 3952,
#  'stipulates': 3950,
#  'putting': 3565,
#  'components': 2072,
#  'adopting': 1649,
#  '18': 139,
#  'directions': 2347,
#  'Auditors': 616,
#  'crystallized': 2232,
#  '57': 448,
#  'differently': 2340,
#  'Claimants': 714,
#  'actualcurrent': 1620,
#  'Employers': 841,
#  'costrate': 2202,
#  'Similar': 1435,
#  'dealt': 2253,
#  'contentions': 2157,
#  'quite': 3580,
#  'elaborately': 2456,
#  'majority': 3093,
#  'members': 3129,
#  'expression': 2594,
#  '703xi': 481,
#  'defined': 2280,
#  'gi': 2733,
#  'reproducing': 3722,
#  'binding': 1910,
#  'concluded': 2086,
#  'expressly': 2596,
#  'mention': 3130,
#  'prices': 3492,
#  'prevalent': 3485,
#  'discussed': 2362,
#  'each': 2439,
#  'every': 2538,
#  'examples': 2549,
#  'quoted': 3581,
#  'consideration': 2121,
#  'argument': 1795,
#  'currentinvoice': 2235,
#  'BOQ': 627,
#  'rational': 3592,
#  'ratio': 3591,
#  'comparable': 2052,
#  'rates': 3588,
#  'Therefore': 1503,
#  'principle': 3497,
#  'rule': 3797,
#  'proferentem': 3521,
#  'means': 3116,
#  'ambiguity': 1710,
#  'found': 2695,
#  'author': 1844,
#  'Undoubtedly': 1530,
#  'Tribunals': 1519,
#  'approached': 1771,
#  'petitions': 3405,
#  '34': 367,
#  'Sudhir': 1468,
#  'Nandrajog': 1139,
#  'ignored': 2825,
#  'cumulative': 2233,
#  'weightage': 4252,
#  'exceed': 2550,
#  '50': 427,
#  'renders': 3708,
#  ...}

# %%
title_bow = bow_transformer.transform(df['text'])

# %%
x = title_bow.toarray()

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer().fit(title_bow)
title_tfidf = tfidf_transformer.transform(title_bow)

# %%
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(title_tfidf, df['class'], test_size = 0.2, random_state = 0)

# %%
model1 = MultinomialNB().fit(X_train, y_train)
model2 = BernoulliNB().fit(X_train, y_train)
model3 = LinearSVC().fit(X_train, y_train)
model4 = LogisticRegression().fit(X_train, y_train)
model5 = KNeighborsClassifier().fit(X_train, y_train)
model6 = DecisionTreeClassifier().fit(X_train, y_train)

# %%
all_pred1 = model1.predict(X_test)
all_pred2 = model2.predict(X_test)
all_pred3 = model3.predict(X_test)
all_pred4 = model4.predict(X_test)
all_pred5 = model5.predict(X_test)
all_pred6 = model6.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, all_pred3)
# Out:
# array([[11,  2,  0,  5],
#        [ 0,  1,  3,  3],
#        [ 0,  1, 15,  1],
#        [ 1,  0,  3, 26]])

# %%
from sklearn.metrics import accuracy_score

# %%
print('MultinomialNB:',accuracy_score(y_test,all_pred1))
print('BernoulliNB:',accuracy_score(y_test,all_pred2))
print('LinearSVC:',accuracy_score(y_test,all_pred3))
print('LogisticRegression:',accuracy_score(y_test,all_pred4))
print('KNeighborsClassifier:',accuracy_score(y_test,all_pred5))
print('DecisionTreeClassifier:',accuracy_score(y_test,all_pred6))
# Out:
# MultinomialNB: 0.4444444444444444
# BernoulliNB: 0.4861111111111111
# LinearSVC: 0.7361111111111112
# LogisticRegression: 0.5972222222222222
# KNeighborsClassifier: 0.5833333333333334
# DecisionTreeClassifier: 0.6527777777777778
