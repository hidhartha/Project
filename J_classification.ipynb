# %%
import pandas as pd
import spacy
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/MyDrive/Colab Notebooks/MTP after 15/JUDGEMENT_EXTRACTION/model_precedent2_pickle_Judgement', 'rb') as f:
  mp = pickle.load(f)

# %%
with open('/content/test_file1.txt') as f:
    x= f.read()

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/MTP after 15/JUDGEMENT_EXTRACTION/judgement classification.xlsx')

# %%
df.head()
# Out:
#                                                 text  label
# 0  In the considered view of the Court, it was no...      0
# 1  The decision of the AT by the impugned Award d...      0
# 2  The petition is dismissed with costs of Rs. 10...      1
# 3  In the light of the law discussed hereinabove ...      0
# 4  In the light of the above discussion, there is...      1

# %%
model_prediction = [0]*len(df)

# %%
df['Model_prediction'] = model_prediction

# %%
df.head()
# Out:
#                                                 text  label  Model_prediction
# 0  In the considered view of the Court, it was no...      0                 0
# 1  The decision of the AT by the impugned Award d...      0                 0
# 2  The petition is dismissed with costs of Rs. 10...      1                 0
# 3  In the light of the law discussed hereinabove ...      0                 0
# 4  In the light of the above discussion, there is...      1                 0

# %%
from collections import defaultdict

# %%
d = defaultdict(lambda:0)

# %%
for i in range(len(df)):
  doc = mp(df['text'][i])
  for ent in doc.ents:
    if ent.label_ == 'COSTS' or ent.label_ == 'DISMISSED' or ent.label_ == 'DISPOSED OF' or ent.label_ == 'APPEAL IS ALLOWED' or ent.label_ == 'CANNOT BE SUSTAINED' or ent.label_ == 'APPEAL IS DISMISSED':
      df['Model_prediction'][i]+=1
    else:
      continue
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
for i in range(len(df)):
  if df['Model_prediction'][i] >=1:
    df['Model_prediction'][i] = 1
  else:
    continue
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df
# Out:
#                                                  text  label  Model_prediction
# 0   In the considered view of the Court, it was no...      0                 0
# 1   The decision of the AT by the impugned Award d...      0                 0
# 2   The petition is dismissed with costs of Rs. 10...      1                 1
# 3   In the light of the law discussed hereinabove ...      0                 0
# 4   In the light of the above discussion, there is...      1                 1
# 5   In view of my finding above, that the order of...      0                 0
# 6   Apart from the consultancy and supervision cha...      0                 1
# 7   In view of the above, I do not find any ground...      0                 0
# 8   The petition is therefore dismissed, however, ...      1                 1
# 9   In the present case, since the contract was co...      0                 0
# 10  Claim No. XV was as regards two items (i) Rs. ...      0                 0
# ...

# %%
y_pred = df['Model_prediction']
y_actual = df['label']

# %%
from sklearn.metrics import accuracy_score
print('Accuracy score: ', accuracy_score(y_actual,y_pred))
# Out:
# Accuracy score:  0.7872340425531915

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_actual, y_pred)
# Out:
# array([[22,  8],
#        [ 2, 15]])
